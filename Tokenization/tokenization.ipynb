# %% [markdown]
# # Installing NLTK

# %% [markdown]
# NLTK (Natural Language Toolkit) is a Python library used for working with human language/text. It is commonly used for learning and implementing basic NLP (Natural Language Processing) techniques.

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
corpus="""I am B.E CSE Student.
And learning NLP !Working toward learning Agentic Ai"""

# %%
print(corpus)
# Out:
# I am B.E CSE Student.
# And learning NLP !Working toward learning Agentic Ai

# %%
## Tokenization 
## Paragraphs --->Sentences
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\s8242\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\s8242\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
document=sent_tokenize(corpus)

# %%
type(document)
# Out:
# list

# %%
for sentence in document:
    print(sentence)
# Out:
# I am B.E CSE Student.
# And learning NLP !Working toward learning Agentic Ai

# %%
##Tokenixation 
##paragraph-->Word
##sentence-->word
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['I',
#  'am',
#  'B.E',
#  'CSE',
#  'Student',
#  '.',
#  'And',
#  'learning',
#  'NLP',
#  '!',
#  'Working',
#  'toward',
#  'learning',
#  'Agentic',
#  'Ai']

# %%
for sentence in document:
    print(word_tokenize(sentence))
# Out:
# ['I', 'am', 'B.E', 'CSE', 'Student', '.']
# ['And', 'learning', 'NLP', '!', 'Working', 'toward', 'learning', 'Agentic', 'Ai']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['I',
#  'am',
#  'B',
#  '.',
#  'E',
#  'CSE',
#  'Student',
#  '.',
#  'And',
#  'learning',
#  'NLP',
#  '!',
#  'Working',
#  'toward',
#  'learning',
#  'Agentic',
#  'Ai']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()
print(tokenizer.tokenize(corpus))
# Out:
# ['I', 'am', 'B.E', 'CSE', 'Student.', 'And', 'learning', 'NLP', '!', 'Working', 'toward', 'learning', 'Agentic', 'Ai']
